# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmadsanafarooq/Data-Science-Machine-Learning-Nodebook/blob/main/DS_3_PART_2_IRIS_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#load dataset
df=pd.read_csv('/content/Iris.csv')

# %% [markdown]
# **Head (1ST 5 VALUES ) & Tail (LAST 5 VALUES)**

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#NORMALIZE
df.Species.value_counts(normalize=True)
# Out:
# Species
# Iris-setosa        0.333333
# Iris-versicolor    0.333333
# Iris-virginica     0.333333
# Name: proportion, dtype: float64

# %%
missing_value=df.isnull().sum()
missing_value
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
duplicate_value=df.duplicated().sum()
duplicate_value
# Out:
# 0

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.drop('Id',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ***SCATTERPLOT***

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=df)
plt.title("PETAL LENGTH VS PETAL WIDTH")
plt.ylabel("PETAL WIDTH")
plt.xlabel("PETAL LENGTH")
plt.show()

# %% [markdown]
# **Iris_setosa** = from 1 to 2
#
# **iris_versicolor** = from approx. 3 to approx. 5.3
#
# **iris_verginiuca** = form approx. 4.6 to 7

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)
plt.title("SEPAL LENGTH VS SEPAL WIDTH")
plt.ylabel("SEPAL WIDTH")
plt.xlabel("SEPAL LENGTH")
plt.show()

# %% [markdown]
# **Iris_setosa** = from approx. 4.2 to approx. 6.0
#
# **iris_versicolor** = from approx. 4.9 to approx. 7.1
#
# **iris_verginice** = from approx. 4.9 to 8.0

# %% [markdown]
# ***PAIR PLOT***

# %%
sns.pairplot(df,hue='Species')
plt.show()

# %% [markdown]
# ***Target Column Bar Plot***

# %%
df.Species.value_counts().plot(kind='bar')
plt.title("VALUE COUNTS OF SPECIES")
plt.xlabel("SPECIES")
plt.xticks(rotation=0)
plt.ylabel("COUNT")
plt.show()

# %% [markdown]
# ***Label Encoding***

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Species']=le.fit_transform(df['Species'])

# %% [markdown]
# ***Correlation***

# %%
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# Species             0.782561     -0.419446       0.949043      0.956464
#
#                 Species
# SepalLengthCm  0.782561
# SepalWidthCm  -0.419446
# PetalLengthCm  0.949043
# PetalWidthCm   0.956464
# Species        1.000000

# %% [markdown]
# ***Correlation Haetmap***

# %%
plt.figure(figsize=(10,10))
correlation_matrix=df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='gist_ncar')
plt.show()

# %% [markdown]
# ***Split Dataset***

# %%
x=df.drop('Species',axis=1)
y=df['Species']

# %% [markdown]
# ***Train Test Split***

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.20)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(Y_test,y_pred)
accuracy=score*100
print(accuracy)
# Out:
# 100.0
